# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

gkey = "AIzaSyDf-kIlaC2eZMYXJ3Nk6BQjeMcpw55vCEQ"

target_city = "Birmingham, UK"

# %%
types_df = pd.read_csv("Resources/ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# set up additional columns to hold information
types_df['name'] = ""
types_df['address'] = ""
types_df['price_level'] = ""
types_df['rating'] = ""

types_df.head()
# Out:
#   ethnicity name address price_level rating
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "52.489471,-1.898575",  # Birmingham coords
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}
# use iterrows to iterate through pandas dataframe
for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = row['ethnicity']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest {restr_type} restaurant is {results[0]['name']}.")
        
        types_df.loc[index, 'name'] = results[0]['name']
        types_df.loc[index, 'address'] = results[0]['vicinity']
        types_df.loc[index, 'price_level'] = results[0]['price_level']
        types_df.loc[index, 'rating'] = results[0]['rating']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: chinese.
# Closest chinese restaurant is Tattu Restaurant and Bar.
# ------------
# Retrieving Results for Index 1: cuban.
# Closest cuban restaurant is Revolución de Cuba Birmingham.
# ------------
# Retrieving Results for Index 2: czech.
# Closest czech restaurant is Syriana Restaurant.
# ------------
# Retrieving Results for Index 3: french.
# Closest french restaurant is Hotel du Vin Birmingham.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 4: german.
# Closest german restaurant is German Doner Kebab.
# ------------
# Retrieving Results for Index 5: greek.
# Closest greek restaurant is Ionic Catering.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 6: haitian.
# Closest haitian restaurant is Bukka Kitchen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: hungarian.
# Closest hungarian restaurant is Saint Pauls House.
# ...

# %%
types_df
# Out:
#        ethnicity                                  name  \
# 0        chinese              Tattu Restaurant and Bar
# 1          cuban         Revolución de Cuba Birmingham
# 2          czech                    Syriana Restaurant
# 3         french               Hotel du Vin Birmingham
# 4         german                    German Doner Kebab
# 5          greek                        Ionic Catering
# 6        haitian                         Bukka Kitchen
# 7      hungarian                     Saint Pauls House
# 8         indian                        Hen & Chickens
# 9     indonesian             Wok&Go - Aston University
# 10         irish             The Alchemist Colmore Row
# 11       israeli                    Syriana Restaurant
# 12       italian          The Birmingham Pizza Company
# 13      japanese                              Kodawari
# 14        jewish                           Deli Heaven
# 15        korean                          Filthy Wings
# ...

# %%
types_df.to_csv("../Resources/data.csv")
